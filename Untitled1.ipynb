# %%
import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# Spiral definition

phi = (1 + math.sqrt(5))/2
spiral1 = lambda c, t, l: math.pow(c, t - 12*math.pi + l)
c1 = math.pow(phi, 1/(2*math.pi)
b = math.arctan(1/math.log(c1))

# Points on spiral
x1, y1, z1 = (-0.17305364, 0.08333824, 0.98138024)
x2, y2, z2 = (-0.29993265, -0.14443995, 0.94296209)
x3, y3, z3 = (0.27325293, 0.34264834, 0.89884646)
              

plt.scatter([x1, x3], [y1, y3], s=10, c='b'  )

# Calculate slope and intercept using two points
def get_equation(p1, p2):
    x1, y1 = p1
    x2, y2 = p2

    m = (y2 - y1)/(x2 - x1)
    b = y1 - m*x1
    return m, b

# Plot line function
def plot_line(x1, x2, m, b, c='red'):
    x = np.linspace(x1, x2, 100)
    y = m*x + b
    plt.plot(x, y, c=c)

# Tangent equations of points in spiral
m1, b1 = get_equation((x1, y1) , (x2, y2))
m2, b2 = get_equation((x3, y3) , (x4, y4))

plot_line(-1, -0.5, m1, b1)
plot_line(-7, -4, m2, b2)

# Calculate radius line of first tangent line
t1 = 1/b
m01 = (m1 - t1)/(m1*t1 + 1)
b01 = y1 - m01*x1
plot_line(-1, 3, m01, b01, c='g')

# Calculate radius line of second tangent line
m02 = (m2 - t1)/(m2*t1 + 1)
b02 = y3 - m02*x3
plot_line(-7, 3, m02, b02, c='g')

# Calculate intersection between the two radius lines
x0 = (b02 - b01)/(m01 - m02)
y0 = m01*x0 + b01
print(x0, y0)
plt.scatter([x0], [y0], s=20, c='black' , zorder=0 )

plt.show()
# Out:
# 2.6216772490942355 3.7334473422531738
